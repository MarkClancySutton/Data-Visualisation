# %% [markdown]
# # Visualising time trends using animation and interactive streams

# %% [markdown]
# # This week's exercise tests your abilities in the following:
#
#  - Preparing your data for animation
#  - Animating your charts, encoding one of the dimensions as an animpation.
#  - Making the chart more attractive and memorable.
#
#  - Using stream charts interactively

# %% [markdown]
# # 1. Prepare
#
#  - Load the libraries (you will need tidyverse, probably zoo, gganimate and gifski.
#  - set the base theme to theme_bw()
#  - Make sure you have a folder allocated for your GIFs.

# %%
shhh <- suppressPackageStartupMessages # It's a library, so shhh!warnings
shhh(library(tidyverse))
library(gganimate)
theme_set(theme_bw())
# Out:
# No renderer backend detected. gganimate will default to writing frames to separate files
# Consider installing:
# - the `gifski` package for gif output
# - the `av` package for video output
# and restarting the R session

# %% [markdown]
# ## 2. Source your data
#
# The Irish Weather monitoring service, Met Eireann, publishes data that has been collected at weather stations over the years.  The data recorded can be hourly, daily or monthly.  Let's focus on monthly data this time around.
#
#  - Go to https://data.gov.ie/organization/meteireann.  In the search box, look for monthly data.  Pick a weather station, first checking that there is valid data there.
#  - Read the data into a dataframe.
#  - Remember that some of the datasets start with comments (see sample code, week 3).
#  - Make sure that the dataset you choose has month and year values (or dates, that you can convert to month and year) and that every row has a value for month and year.

# %%
mydata = file.path("C:","Users","markc","Desktop","DataVisuals","datasets")

datapath <-file.path(mydata,'weather.csv')
dfdub<-read.csv(datapath)
head(dfdub)
# Out:
#   year month meant maxtp mintp mnmax mnmin rain  gmin wdsp maxgt sun
# 1 2004  8    15.8  21.4  8.7   18.5  13.1  138.2  4.6 10.7 36    NA
# 2 2004  9    14.7  23.2  7.2   17.7  11.7   93.7  3.5 12.7 48    NA
# 3 2004 10    10.5  16.3  3.5   13.6   7.5  143.7 -1.1 13.7 50    NA
# 4 2004 11     9.7  14.6  2.5   11.9   7.5   24.9 -3.7 10.9 41    NA
# 5 2004 12     8.5  14.2  0.6   10.5   6.4   49.7 -1.8 12.9 68    NA
# 6 2005  1     7.9  13.4  0.9   10.4   5.5   75.1 -5.0 17.1 71    NA

# %% [markdown]
# ## 3. Check out your data:
#  - What is the structure? (str)
#  - Check the summary - what is the range of each value?  Are there many NAs?
#  - How many unique values are there for each variable?
#      - df %>% summarise_all(n_distinct)
#  - Is there any column that only has a few values, so could be used for small multiples or stacking?
#  - Are there columns that have more or less the same range of values?  Maybe that could be pivoted and used for stacking?
#  - Is there any column you could use to change the size in a point chart?

# %%
str(dfdub)
# Out:
# 'data.frame':	233 obs. of  12 variables:
#  $ year : int  2004 2004 2004 2004 2004 2005 2005 2005 2005 2005 ...
#  $ month: int  8 9 10 11 12 1 2 3 4 6 ...
#  $ meant: num  15.8 14.7 10.5 9.7 8.5 7.9 6 8 8.7 14.5 ...
#  $ maxtp: num  21.4 23.2 16.3 14.6 14.2 13.4 13.6 13.6 13.9 21.5 ...
#  $ mintp: num  8.7 7.2 3.5 2.5 0.6 0.9 -0.7 0.1 1.7 7.1 ...
#  $ mnmax: num  18.5 17.7 13.6 11.9 10.5 10.4 8.5 10.2 11.8 17.3 ...
#  $ mnmin: num  13.1 11.7 7.5 7.5 6.4 5.5 3.5 5.9 5.6 11.6 ...
#  $ rain : num  138.2 93.7 143.7 24.9 49.7 ...
#  $ gmin : num  4.6 3.5 -1.1 -3.7 -1.8 -5 -8.5 -6.3 -2.1 1.4 ...
#  $ wdsp : num  10.7 12.7 13.7 10.9 12.9 17.1 12.3 12 11.6 9.7 ...
#  $ maxgt: int  36 48 50 41 68 71 52 38 47 32 ...
#  $ sun  : logi  NA NA NA NA NA NA ...

# %%
unique(dfdub$year)
# Out:
#  [1] 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018
# [16] 2019 2020 2021 2022 2023 2024

# %%
unique(dfdub$month)
# Out:
#  [1]  8  9 10 11 12  1  2  3  4  6  7  5

# %%
head(dfdub,2)
# Out:
#   year month meant maxtp mintp mnmax mnmin rain  gmin wdsp maxgt sun
# 1 2004 8     15.8  21.4  8.7   18.5  13.1  138.2 4.6  10.7 36    NA
# 2 2004 9     14.7  23.2  7.2   17.7  11.7   93.7 3.5  12.7 48    NA

# %%
dfdub %>% summarise_all(n_distinct)
# Out:
#   year month meant maxtp mintp mnmax mnmin rain gmin wdsp maxgt sun
# 1 21   12    99    117   114   106   99    220  113  78   44    1

# %% [markdown]
# # 4. Tidy and manipulate the data
#
#  - You will need to have three numeric dimensions, one encoded on the x-axis, one encoded on the y-axis and one encoded as animation.
#  - You will need at least one (2 is better!) categorical dimensions to enhance the initial static chart.
#
#  **Remember that each row may need to have a value for each dimension and each row should be unique*

# %% [markdown]
# ## 6. Chart
# - Generate a single line chart, with just 2 dimensions.
#
# - Convert it to a point chart.
# - Enhance it with one or two other dimensions.
#
# - Generate a transition_time and a time_reveal chart, saving each and displaying your GIF.

# %%
library(ggplot2)

# Assuming 'month' is a variable in dfdub that represents the month
# You may need to adjust this depending on the structure of your data

#Static plot
p <- ggplot(
  dfdub, 
  aes(x = maxtp, y = mintp)
) +
  geom_point(show.legend = FALSE, alpha = 0.7) +
  scale_color_viridis_d() +
  scale_size(range = c(2, 12)) +
  scale_x_log10() +
  labs(x = "Max Temperature ° Celcius", y = "Min Temperature ° Celcius")

p
# Out:
# plot without title

# %%
display_gif <- function(raw){
    contents <- base64enc::base64encode(raw)
    tag <- '<img src="data:image/gif;base64,%s">'
    IRdisplay::display_html(sprintf(tag, contents))
}

# %%
p + transition_time(year) +
  labs(title = "Year: {frame_time}")
# Out:
# Rendering [>-------------------------------------------] at 6.9 fps ~ eta: 14s
#
# Rendering [>-------------------------------------------] at 7.1 fps ~ eta: 14s
#
# Rendering [=>------------------------------------------] at 7.4 fps ~ eta: 13s
#
# Rendering [==>-----------------------------------------] at 7.6 fps ~ eta: 12s
#
# Rendering [===>----------------------------------------] at 7.8 fps ~ eta: 12s
#
# Rendering [===>----------------------------------------] at 7.9 fps ~ eta: 11s
#
# Rendering [===>----------------------------------------] at 7.7 fps ~ eta: 12s
#
# Rendering [====>---------------------------------------] at 7.8 fps ~ eta: 11s
#
# Rendering [====>---------------------------------------] at 7.9 fps ~ eta: 11s
#
# Rendering [=====>--------------------------------------] at 7.8 fps ~ eta: 11s
#
# Rendering [=====>--------------------------------------] at 7.9 fps ~ eta: 11s
#
# Rendering [======>-------------------------------------] at 7.9 fps ~ eta: 11s
#
# Rendering [======>-------------------------------------] at 7.8 fps ~ eta: 11s
#
# Rendering [=======>------------------------------------] at 7.8 fps ~ eta: 10s
#
# Rendering [=======>------------------------------------] at 7.7 fps ~ eta: 10s
#
# Rendering [========>-----------------------------------] at 7.8 fps ~ eta: 10s
#
# Rendering [========>-----------------------------------] at 7.7 fps ~ eta: 10s
#
# Rendering [=========>----------------------------------] at 7.8 fps ~ eta: 10s
#
# Rendering [==========>---------------------------------] at 7.8 fps ~ eta: 10s
#
# Rendering [==========>---------------------------------] at 7.9 fps ~ eta:  9s
#
# Rendering [===========>----------------------------------] at 8 fps ~ eta:  9s
#
# Rendering [============>---------------------------------] at 8 fps ~ eta:  9s
#
# Rendering [=============>--------------------------------] at 8 fps ~ eta:  9s
#
# Rendering [=============>------------------------------] at 8.1 fps ~ eta:  8s
#
# Rendering [==============>-----------------------------] at 8.1 fps ~ eta:  8s
#
# Rendering [===============>----------------------------] at 8.2 fps ~ eta:  8s
#
# Rendering [================>---------------------------] at 8.2 fps ~ eta:  8s
#
# Rendering [================>---------------------------] at 8.2 fps ~ eta:  7s
#
# Rendering [=================>--------------------------] at 8.1 fps ~ eta:  7s
#
# Rendering [==================>---------------------------] at 8 fps ~ eta:  7s
#
# Rendering [===================>--------------------------] at 8 fps ~ eta:  7s
#
# Rendering [==================>-------------------------] at 7.9 fps ~ eta:  7s
#
# Rendering [====================>-------------------------] at 8 fps ~ eta:  7s
#
# Rendering [===================>------------------------] at 7.9 fps ~ eta:  7s
#
# Rendering [====================>-----------------------] at 7.9 fps ~ eta:  7s
#
# Rendering [=====================>----------------------] at 7.9 fps ~ eta:  6s
#
# Rendering [=====================>----------------------] at 7.8 fps ~ eta:  6s
#
# Rendering [======================>---------------------] at 7.9 fps ~ eta:  6s
#
# Rendering [=======================>--------------------] at 7.9 fps ~ eta:  6s
#
# Rendering [=======================>--------------------] at 7.8 fps ~ eta:  6s
#
# Rendering [========================>-------------------] at 7.8 fps ~ eta:  6s
#
# Rendering [=========================>------------------] at 7.8 fps ~ eta:  5s
#
# Rendering [=========================>------------------] at 7.9 fps ~ eta:  5s
#
# Rendering [==========================>-----------------] at 7.8 fps ~ eta:  5s
#
# Rendering [===========================>----------------] at 7.8 fps ~ eta:  5s
#
# Rendering [============================>---------------] at 7.8 fps ~ eta:  4s
#
# Rendering [=============================>--------------] at 7.8 fps ~ eta:  4s
#
# Rendering [==============================>-------------] at 7.8 fps ~ eta:  4s
#
# Rendering [===============================>------------] at 7.8 fps ~ eta:  4s
#
# Rendering [===============================>------------] at 7.8 fps ~ eta:  3s
#
# Rendering [================================>-----------] at 7.7 fps ~ eta:  3s
#
# Rendering [=================================>----------] at 7.7 fps ~ eta:  3s
#
# Rendering [=================================>----------] at 7.6 fps ~ eta:  3s
#
# Rendering [==================================>---------] at 7.6 fps ~ eta:  3s
#
# Rendering [===================================>--------] at 7.6 fps ~ eta:  3s
#
# Rendering [===================================>--------] at 7.5 fps ~ eta:  2s
#
# Rendering [====================================>-------] at 7.5 fps ~ eta:  2s
#
# Rendering [=====================================>------] at 7.5 fps ~ eta:  2s
#
# Rendering [======================================>-----] at 7.5 fps ~ eta:  2s
#
# Rendering [======================================>-----] at 7.5 fps ~ eta:  1s
#
# Rendering [=======================================>----] at 7.5 fps ~ eta:  1s
#
# Rendering [========================================>---] at 7.5 fps ~ eta:  1s
#
# Rendering [=========================================>--] at 7.5 fps ~ eta:  1s
#
# Rendering [==========================================>-] at 7.5 fps ~ eta:  0s
#
# Rendering [===========================================>] at 7.5 fps ~ eta:  0s
#
# Rendering [============================================] at 7.5 fps ~ eta:  0s
#
#
# Warning message:
# "file_renderer failed to copy frames to the destination directory"
#   [1] "./gganim_plot0001.png" "./gganim_plot0002.png" "./gganim_plot0003.png"
#   [4] "./gganim_plot0004.png" "./gganim_plot0005.png" "./gganim_plot0006.png"
#   [7] "./gganim_plot0007.png" "./gganim_plot0008.png" "./gganim_plot0009.png"
#  [10] "./gganim_plot0010.png" "./gganim_plot0011.png" "./gganim_plot0012.png"
#  [13] "./gganim_plot0013.png" "./gganim_plot0014.png" "./gganim_plot0015.png"
#  [16] "./gganim_plot0016.png" "./gganim_plot0017.png" "./gganim_plot0018.png"
#  [19] "./gganim_plot0019.png" "./gganim_plot0020.png" "./gganim_plot0021.png"
#  [22] "./gganim_plot0022.png" "./gganim_plot0023.png" "./gganim_plot0024.png"
#  [25] "./gganim_plot0025.png" "./gganim_plot0026.png" "./gganim_plot0027.png"
#  [28] "./gganim_plot0028.png" "./gganim_plot0029.png" "./gganim_plot0030.png"
#  [31] "./gganim_plot0031.png" "./gganim_plot0032.png" "./gganim_plot0033.png"
#  [34] "./gganim_plot0034.png" "./gganim_plot0035.png" "./gganim_plot0036.png"
#  [37] "./gganim_plot0037.png" "./gganim_plot0038.png" "./gganim_plot0039.png"
#  [40] "./gganim_plot0040.png" "./gganim_plot0041.png" "./gganim_plot0042.png"
#  [43] "./gganim_plot0043.png" "./gganim_plot0044.png" "./gganim_plot0045.png"
#  [46] "./gganim_plot0046.png" "./gganim_plot0047.png" "./gganim_plot0048.png"
#  [49] "./gganim_plot0049.png" "./gganim_plot0050.png" "./gganim_plot0051.png"
#  [52] "./gganim_plot0052.png" "./gganim_plot0053.png" "./gganim_plot0054.png"
#  [55] "./gganim_plot0055.png" "./gganim_plot0056.png" "./gganim_plot0057.png"
#  [58] "./gganim_plot0058.png" "./gganim_plot0059.png" "./gganim_plot0060.png"
#  [61] "./gganim_plot0061.png" "./gganim_plot0062.png" "./gganim_plot0063.png"
#  [64] "./gganim_plot0064.png" "./gganim_plot0065.png" "./gganim_plot0066.png"
#  [67] "./gganim_plot0067.png" "./gganim_plot0068.png" "./gganim_plot0069.png"
#  [70] "./gganim_plot0070.png" "./gganim_plot0071.png" "./gganim_plot0072.png"
#  [73] "./gganim_plot0073.png" "./gganim_plot0074.png" "./gganim_plot0075.png"
#  [76] "./gganim_plot0076.png" "./gganim_plot0077.png" "./gganim_plot0078.png"
#  [79] "./gganim_plot0079.png" "./gganim_plot0080.png" "./gganim_plot0081.png"
#  [82] "./gganim_plot0082.png" "./gganim_plot0083.png" "./gganim_plot0084.png"
#  [85] "./gganim_plot0085.png" "./gganim_plot0086.png" "./gganim_plot0087.png"
#  [88] "./gganim_plot0088.png" "./gganim_plot0089.png" "./gganim_plot0090.png"
#  [91] "./gganim_plot0091.png" "./gganim_plot0092.png" "./gganim_plot0093.png"
#  [94] "./gganim_plot0094.png" "./gganim_plot0095.png" "./gganim_plot0096.png"
#  [97] "./gganim_plot0097.png" "./gganim_plot0098.png" "./gganim_plot0099.png"
# [100] "./gganim_plot0100.png"
# attr(,"frame_vars")
#     frame nframes progress frame_time
# 1       1     100     0.01       2004
# 2       2     100     0.02       2004
# 3       3     100     0.03       2004
# 4       4     100     0.04       2005
# 5       5     100     0.05       2005
# 6       6     100     0.06       2005
# 7       7     100     0.07       2005
# 8       8     100     0.08       2005
# 9       9     100     0.09       2006
# 10     10     100     0.10       2006
# 11     11     100     0.11       2006
# 12     12     100     0.12       2006
# 13     13     100     0.13       2006
# 14     14     100     0.14       2007
# 15     15     100     0.15       2007
# 16     16     100     0.16       2007
# 17     17     100     0.17       2007
# 18     18     100     0.18       2007
# 19     19     100     0.19       2008
# 20     20     100     0.20       2008
# 21     21     100     0.21       2008
# 22     22     100     0.22       2008
# 23     23     100     0.23       2008
# 24     24     100     0.24       2009
# 25     25     100     0.25       2009
# 26     26     100     0.26       2009
# 27     27     100     0.27       2009
# 28     28     100     0.28       2009
# 29     29     100     0.29       2010
# 30     30     100     0.30       2010
# 31     31     100     0.31       2010
# 32     32     100     0.32       2010
# 33     33     100     0.33       2010
# 34     34     100     0.34       2011
# 35     35     100     0.35       2011
# 36     36     100     0.36       2011
# 37     37     100     0.37       2011
# 38     38     100     0.38       2011
# 39     39     100     0.39       2012
# 40     40     100     0.40       2012
# 41     41     100     0.41       2012
# 42     42     100     0.42       2012
# 43     43     100     0.43       2012
# 44     44     100     0.44       2013
# 45     45     100     0.45       2013
# 46     46     100     0.46       2013
# 47     47     100     0.47       2013
# 48     48     100     0.48       2013
# 49     49     100     0.49       2014
# 50     50     100     0.50       2014
# 51     51     100     0.51       2014
# 52     52     100     0.52       2014
# 53     53     100     0.53       2015
# 54     54     100     0.54       2015
# 55     55     100     0.55       2015
# 56     56     100     0.56       2015
# 57     57     100     0.57       2015
# 58     58     100     0.58       2016
# 59     59     100     0.59       2016
# 60     60     100     0.60       2016
# 61     61     100     0.61       2016
# 62     62     100     0.62       2016
# 63     63     100     0.63       2017
# 64     64     100     0.64       2017
# 65     65     100     0.65       2017
# 66     66     100     0.66       2017
# 67     67     100     0.67       2017
# 68     68     100     0.68       2018
# 69     69     100     0.69       2018
# 70     70     100     0.70       2018
# 71     71     100     0.71       2018
# 72     72     100     0.72       2018
# 73     73     100     0.73       2019
# 74     74     100     0.74       2019
# 75     75     100     0.75       2019
# 76     76     100     0.76       2019
# 77     77     100     0.77       2019
# 78     78     100     0.78       2020
# 79     79     100     0.79       2020
# 80     80     100     0.80       2020
# 81     81     100     0.81       2020
# 82     82     100     0.82       2020
# 83     83     100     0.83       2021
# 84     84     100     0.84       2021
# 85     85     100     0.85       2021
# 86     86     100     0.86       2021
# 87     87     100     0.87       2021
# 88     88     100     0.88       2022
# 89     89     100     0.89       2022
# 90     90     100     0.90       2022
# 91     91     100     0.91       2022
# 92     92     100     0.92       2022
# 93     93     100     0.93       2023
# 94     94     100     0.94       2023
# 95     95     100     0.95       2023
# 96     96     100     0.96       2023
# 97     97     100     0.97       2023
# 98     98     100     0.98       2024
# 99     99     100     0.99       2024
# 100   100     100     1.00       2024
#                                                                             frame_source
# 1   C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0001.png
# 2   C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0002.png
# 3   C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0003.png
# 4   C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0004.png
# 5   C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0005.png
# 6   C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0006.png
# 7   C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0007.png
# 8   C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0008.png
# 9   C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0009.png
# 10  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0010.png
# 11  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0011.png
# 12  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0012.png
# 13  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0013.png
# 14  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0014.png
# 15  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0015.png
# 16  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0016.png
# 17  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0017.png
# 18  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0018.png
# 19  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0019.png
# 20  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0020.png
# 21  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0021.png
# 22  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0022.png
# 23  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0023.png
# 24  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0024.png
# 25  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0025.png
# 26  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0026.png
# 27  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0027.png
# 28  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0028.png
# 29  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0029.png
# 30  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0030.png
# 31  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0031.png
# 32  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0032.png
# 33  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0033.png
# 34  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0034.png
# 35  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0035.png
# 36  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0036.png
# 37  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0037.png
# 38  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0038.png
# 39  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0039.png
# 40  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0040.png
# 41  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0041.png
# 42  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0042.png
# 43  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0043.png
# 44  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0044.png
# 45  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0045.png
# 46  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0046.png
# 47  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0047.png
# 48  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0048.png
# 49  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0049.png
# 50  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0050.png
# 51  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0051.png
# 52  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0052.png
# 53  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0053.png
# 54  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0054.png
# 55  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0055.png
# 56  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0056.png
# 57  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0057.png
# 58  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0058.png
# 59  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0059.png
# 60  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0060.png
# 61  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0061.png
# 62  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0062.png
# 63  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0063.png
# 64  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0064.png
# 65  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0065.png
# 66  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0066.png
# 67  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0067.png
# 68  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0068.png
# 69  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0069.png
# 70  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0070.png
# 71  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0071.png
# 72  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0072.png
# 73  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0073.png
# 74  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0074.png
# 75  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0075.png
# 76  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0076.png
# 77  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0077.png
# 78  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0078.png
# 79  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0079.png
# 80  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0080.png
# 81  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0081.png
# 82  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0082.png
# 83  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0083.png
# 84  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0084.png
# 85  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0085.png
# 86  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0086.png
# 87  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0087.png
# 88  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0088.png
# 89  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0089.png
# 90  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0090.png
# 91  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0091.png
# 92  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0092.png
# 93  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0093.png
# 94  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0094.png
# 95  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0095.png
# 96  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0096.png
# 97  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0097.png
# 98  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0098.png
# 99  C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0099.png
# 100 C:\\Users\\markc\\AppData\\Local\\Temp\\RtmpGcoWwR\\271457656c46/gganim_plot0100.png

# %%
# Generate the animation first
animated_plot <- p +
  transition_time(month) +
  labs(title = "Month: {frame_time}")

# Save the animation
anim_save(file.path("GM1.gif"), animate(animated_plot))

display_gif(file.path("GM1.gif"))
# Out:
# Rendering [>-------------------------------------------] at 8.7 fps ~ eta: 11s
#
# Rendering [>-------------------------------------------] at 7.6 fps ~ eta: 13s
#
# Rendering [=>------------------------------------------] at 7.6 fps ~ eta: 13s
#
# Rendering [=>------------------------------------------] at 7.7 fps ~ eta: 12s
#
# Rendering [==>-----------------------------------------] at 7.7 fps ~ eta: 12s
#
# Rendering [==>-----------------------------------------] at 7.8 fps ~ eta: 12s
#
# Rendering [===>------------------------------------------] at 8 fps ~ eta: 12s
#
# Rendering [===>----------------------------------------] at 7.9 fps ~ eta: 11s
#
# Rendering [====>-----------------------------------------] at 8 fps ~ eta: 11s
#
# Rendering [====>---------------------------------------] at 8.2 fps ~ eta: 11s
#
# Rendering [=====>--------------------------------------] at 8.1 fps ~ eta: 11s
#
# Rendering [=====>--------------------------------------] at 8.2 fps ~ eta: 10s
#
# Rendering [======>---------------------------------------] at 8 fps ~ eta: 11s
#
# Rendering [======>---------------------------------------] at 8 fps ~ eta: 10s
#
# Rendering [======>-------------------------------------] at 7.9 fps ~ eta: 10s
#
# Rendering [=======>--------------------------------------] at 8 fps ~ eta: 10s
#
# Rendering [========>-------------------------------------] at 8 fps ~ eta: 10s
#
# Rendering [========>-----------------------------------] at 8.1 fps ~ eta: 10s
#
# Rendering [=========>----------------------------------] at 8.1 fps ~ eta: 10s
#
# Rendering [==========>---------------------------------] at 8.1 fps ~ eta:  9s
#
# Rendering [===========>--------------------------------] at 8.2 fps ~ eta:  9s
#
# Rendering [============>-------------------------------] at 8.1 fps ~ eta:  9s
#
# Rendering [=============>------------------------------] at 8.1 fps ~ eta:  9s
#
# Rendering [==============>-------------------------------] at 8 fps ~ eta:  8s
#
# Rendering [===============>------------------------------] at 8 fps ~ eta:  8s
#
# Rendering [===============>----------------------------] at 8.1 fps ~ eta:  8s
#
# Rendering [================>---------------------------] at 8.1 fps ~ eta:  8s
#
# Rendering [=================>--------------------------] at 8.2 fps ~ eta:  7s
#
# Rendering [=================>--------------------------] at 8.1 fps ~ eta:  7s
#
# Rendering [==================>-------------------------] at 8.2 fps ~ eta:  7s
#
# Rendering [===================>------------------------] at 8.2 fps ~ eta:  7s
#
# Rendering [====================>-----------------------] at 8.2 fps ~ eta:  6s
#
# Rendering [=====================>----------------------] at 8.2 fps ~ eta:  6s
#
# Rendering [======================>---------------------] at 8.2 fps ~ eta:  6s
#
# Rendering [=======================>--------------------] at 8.2 fps ~ eta:  6s
#
# Rendering [========================>-------------------] at 8.1 fps ~ eta:  5s
#
# Rendering [=========================>------------------] at 8.1 fps ~ eta:  5s
#
# Rendering [==========================>-----------------] at 8.1 fps ~ eta:  5s
#
# Rendering [===========================>----------------] at 8.1 fps ~ eta:  5s
#
# Rendering [===========================>----------------] at 8.1 fps ~ eta:  4s
#
# Rendering [============================>---------------] at 8.1 fps ~ eta:  4s
#
# Rendering [=============================>----------------] at 8 fps ~ eta:  4s
#
# Rendering [==============================>---------------] at 8 fps ~ eta:  4s
#
# Rendering [===============================>--------------] at 8 fps ~ eta:  4s
#
# Rendering [================================>-------------] at 8 fps ~ eta:  4s
#
# Rendering [===============================>------------] at 7.9 fps ~ eta:  4s
#
# Rendering [===============================>------------] at 7.9 fps ~ eta:  3s
#
# Rendering [================================>-----------] at 7.9 fps ~ eta:  3s
#
# Rendering [=================================>----------] at 7.9 fps ~ eta:  3s
#
# Rendering [==================================>---------] at 7.9 fps ~ eta:  3s
#
# Rendering [==================================>---------] at 7.8 fps ~ eta:  3s
#
# Rendering [===================================>--------] at 7.8 fps ~ eta:  2s
#
# Rendering [====================================>-------] at 7.8 fps ~ eta:  2s
#
# Rendering [====================================>-------] at 7.7 fps ~ eta:  2s
#
# Rendering [=====================================>------] at 7.7 fps ~ eta:  2s
#
# Rendering [======================================>-----] at 7.7 fps ~ eta:  2s
#
# Rendering [======================================>-----] at 7.7 fps ~ eta:  1s
#
# Rendering [=======================================>----] at 7.7 fps ~ eta:  1s
#
# Rendering [========================================>---] at 7.7 fps ~ eta:  1s
#
# Rendering [========================================>---] at 7.6 fps ~ eta:  1s
#
# Rendering [=========================================>--] at 7.6 fps ~ eta:  1s
#
# Rendering [==========================================>-] at 7.6 fps ~ eta:  0s
#
# Rendering [===========================================>] at 7.6 fps ~ eta:  0s
#
# Rendering [============================================] at 7.6 fps ~ eta:  0s
#
#
# Warning message:
# "file_renderer failed to copy frames to the destination directory"
# Error: The animation object does not specify a save_animation method
# Traceback:
#
# 1. anim_save(file.path("GM1.gif"), animate(animated_plot))
# 2. save_animation(animation, filename)
# 3. save_animation.default(animation, filename)
# 4. stop("The animation object does not specify a save_animation method",
#  .     call. = FALSE)

# %% [markdown]
# ## 7. Install and load the streamgraph package
#  - Copy the code from https://hrbrmstr.github.io/streamgraph/
#  - Adapt the code, to show names around your own name.
#
# With a new dataset:
# - Read in the "vaccine-preventable-disease-cases-by-county-and-year-2.csv"
# - Generate a streamgraph showing vaccinations across the years
#     - You can decide on the breakdown of what is displayed.
